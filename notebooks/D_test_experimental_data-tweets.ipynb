# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
fig_width = 12
# %matplotlib inline

# %%
import bayesianchangepoint as bcp

# %% [markdown]
# ## performing inference: application to experimental data
#
# As a source of quasi-random binary events, let's get some data: https://github.com/bpb27/trump_tweet_data_archive

# %%
from io import BytesIO
from zipfile import ZipFile
import urllib.request
import json
years = [8] #[2, 3, 4, 5, 6, 7]
years = [6, 7]
years = [2, 3, 4, 5, 6, 7, 8]
years = [7, 8]
years = [5, 6, 7]#, 8]
suffix = ''
for year in years: suffix += str(year)
    
datafile = '/tmp/trumpets' + suffix +  '.json'

try:
    with open(datafile, 'r') as f:
        data = json.load(f)
except:

    data = []
    arctype = 'condensed'
    arctype = 'master'
    for year in years:
        url = f"https://github.com/bpb27/trump_tweet_data_archive/blob/master/{arctype}_201{year}.json.zip?raw=true"
        print('Downloading ', url, '...')
        with ZipFile(BytesIO(urllib.request.urlopen(url).read())) as my_zip_file:
            for contained_file in my_zip_file.namelist():
                with my_zip_file.open(contained_file) as f:
                    #data.extend(json.load(f))
                    data.extend(json.loads(f.read().decode('utf-8')))
    with open(datafile, 'w') as f:
        json.dump(data, f)
# Out:
# Downloading  https://github.com/bpb27/trump_tweet_data_archive/blob/master/master_2015.json.zip?raw=true ...
# Downloading  https://github.com/bpb27/trump_tweet_data_archive/blob/master/master_2016.json.zip?raw=true ...
# Downloading  https://github.com/bpb27/trump_tweet_data_archive/blob/master/master_2017.json.zip?raw=true ...

# %%
# !ls -ltrh /tmp/*json
# Out:
# -rw-r--r--  1 laurentperrinet  wheel    44M Mar 25 13:17 /tmp/trumpets567.json

# %% [raw]
# !rm -fr /tmp/trumpets*.json

# %%
n_tweets = len(data)
print('number ow tweets=', n_tweets)
# Out:
# number ow tweets= 14366

# %% [markdown]
# ## example tweet

# %%
i_sample = 42
i_sample = 1973
d = data[i_sample]
d#.keys()#['followers_count']
# Out:
# {'contributors': None,
#  'truncated': False,
#  'text': '"@polina6: @realDonaldTrump MAN WITH A PLAN-THE BEST TAX PLAN! GO TRUMP 2016!"',
#  'is_quote_status': False,
#  'in_reply_to_status_id': None,
#  'id': 648706734270382080,
#  'favorite_count': 3251,
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'retweeted': False,
#  'coordinates': None,
#  'entities': {'symbols': [],
#   'user_mentions': [{'id': 18281493,
#     'indices': [1, 9],
#     'id_str': '18281493',
#     'screen_name': 'polina6',
#     'name': 'polina6'},
#    {'id': 25073877,
#     'indices': [11, 27],
#     'id_str': '25073877',
#     'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump'}],
#   'hashtags': [],
#   'urls': []},
#  'in_reply_to_screen_name': None,
#  'id_str': '648706734270382080',
#  'retweet_count': 1306,
#  'in_reply_to_user_id': None,
#  'favorited': False,
#  'user': {'follow_request_sent': False,
#   'has_extended_profile': False,
#   'profile_use_background_image': True,
#   'geo_enabled': True,
#   'description': 'President-elect of the United States',
#   'verified': True,
#   'entities': {'url': {'urls': [{'indices': [0, 23],
#       'url': 'https://t.co/mZB2hymxC9',
#       'expanded_url': 'http://www.DonaldJTrump.com',
#       'display_url': 'DonaldJTrump.com'}]},
#    'description': {'urls': []}},
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg',
#   'profile_sidebar_fill_color': 'C5CEC0',
#   'id': 25073877,
#   'profile_text_color': '333333',
#   'followers_count': 15668336,
#   'protected': False,
#   'location': 'New York, NY',
#   'default_profile_image': False,
#   'listed_count': 45254,
#   'is_translation_enabled': True,
#   'utc_offset': -18000,
#   'statuses_count': 34010,
#   'translator_type': 'none',
#   'friends_count': 41,
#   'profile_link_color': '0D5B73',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg',
#   'is_translator': False,
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg',
#   'profile_background_color': '6D5C18',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1479267159',
#   'id_str': '25073877',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg',
#   'name': 'Donald J. Trump',
#   'lang': 'en',
#   'profile_background_tile': True,
#   'favourites_count': 45,
#   'screen_name': 'realDonaldTrump',
#   'notifications': True,
#   'url': 'https://t.co/mZB2hymxC9',
#   'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#   'contributors_enabled': False,
#   'time_zone': 'Eastern Time (US & Canada)',
#   'profile_sidebar_border_color': 'BDDCAD',
#   'default_profile': False,
#   'following': True},
#  'geo': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'created_at': 'Tue Sep 29 03:51:52 +0000 2015',
#  'in_reply_to_status_id_str': None,
#  'place': None}

# %% [markdown]
# ## learning to handle datetimes
#
# https://docs.python.org/3/library/datetime.html

# %%
followers = [data[i]['user']['followers_count'] for i in range(n_tweets)]
fig, ax = plt.subplots(figsize=(fig_width, fig_width/1.6180))
ax.plot(followers);

# %%
data_texts = []
for i_tweet in range(n_tweets):
    try:
        data_texts.append(data[i_sample]['full_text'].lower())
    except KeyError:
        data_texts.append(data[i_sample]['text'].lower())

data_texts[i_sample]
# Out:
# '"@polina6: @realdonaldtrump man with a plan-the best tax plan! go trump 2016!"'

# %%
word = 'america'
word = '?'
contains_word = np.array([(word in data_text) for data_text in data_texts])
print(sum(contains_word), 'tweets contain the word "', word, '" on a total of ', n_tweets, 'tweets')
# Out:
# 0 tweets contain the word " ? " on a total of  14366 tweets

# %%
datetimes = [data[i]['created_at'] for i in range(n_tweets)]
print('|'+datetimes[0]+'|')
# Out:
# |Thu Dec 31 23:21:49 +0000 2015|

# %%
import locale
locale.getlocale()
# Out:
# ('en_US', 'UTF-8')

# %%
from datetime import datetime

datetimes = [datetime.strptime(data[i]['created_at'], '%a %b %d %H:%M:%S %z %Y') for i in range(n_tweets)]
print('Timestamp=', datetimes[0].timestamp())
# Out:
# Timestamp= 1451604109.0

# %%
from datetime import datetime

datetimes = np.array([datetime.strptime(data[i]['created_at'], '%a %b %d %H:%M:%S %z %Y').timestamp() for i in range(n_tweets)])
print('Timestamp=', (datetimes[0]))
# Out:
# Timestamp= 1451604109.0

# %%
from datetime import datetime

datetimes = [datetime.strptime(data[i]['created_at'], '%a %b %d %H:%M:%S %z %Y') for i in range(n_tweets)]
print('Timestamp=', datetimes[0].timestamp())
# Out:
# Timestamp= 1451604109.0

# %%
fig_width = 13
fig, ax = plt.subplots(figsize=(fig_width, fig_width/1.6180))
ax.plot(datetimes);

# %% [markdown]
# It seems that within each year, tweets are in inverse chronological order.
# Let's sort things:

# %%
datetimes = np.array(datetimes)
ind_tweets = np.argsort(datetimes)

fig, ax = plt.subplots(figsize=(fig_width, fig_width/1.6180))
ax.plot(datetimes[ind_tweets]);

# %% [markdown]
# We will be using https://matplotlib.org/examples/api/date_demo.html

# %% [markdown]
# ## evolution of followers

# %%
import datetime
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
yearsFmt = mdates.DateFormatter('%Y')

monthsFmt = mdates.DateFormatter('%Y-%m')

# %%
followers = np.array([data[i]['user']['followers_count'] for i in range(n_tweets)])

fig_width = 13
fig, ax = plt.subplots(figsize=(fig_width, fig_width/1.6180))
ax.plot(datetimes[ind_tweets], followers[ind_tweets])
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(yearsFmt)
ax.xaxis.set_minor_locator(months)
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d');

# %% [markdown]
# Personal note: I can not understand the evolution of this curve for a person in real life....

# %%
i= 42
data_texts = []
for i in range(n_tweets):
    try:
        data_texts.append(data[i]['full_text'].lower())
    except KeyError:
        data_texts.append(data[i]['text'].lower())

data_texts[i]
# Out:
# 'to all americans-\n#happynewyear &amp; many blessings to you all! looking forward to a wonderful &amp; prosperous 2017 as we… https://t.co/1asdmal4iy'

# %% [markdown]
# ## detecting change points for using Android (from him) vs iPhone (from staff)

# %% [markdown]
# Detecting tweets from staff (see http://varianceexplained.org/r/trump-tweets/)

# %%
data[i_sample]['source']
# Out:
# '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'

# %%
'iPhone' in data[i_sample]['source']
# Out:
# False

# %%
data_mobileos = np.array([('iPhone' in tweet['source']) for tweet in data])
print(sum(data_mobileos), 'tweets from an iPhone on a total of ', n_tweets, 'tweets')
p0 = sum(data_mobileos) / n_tweets
print('That is, an average probability of p0= ', p0)
# Out:
# 4475 tweets from an iPhone on a total of  14366 tweets
# That is, an average probability of p0=  0.311499373520813

# %%
p0 = .5
for h in [1/1500/(2**k) for k in range(5)]:
    print('tau', 1/h)
    max_run_length = int(6/h)

    p_bar, r, beliefs = bcp.inference(data_mobileos[ind_tweets], h=h, p0=p0)

    fig, axs = bcp.plot_inference(data_mobileos[ind_tweets], None, p_bar, r, beliefs, 
                                  mode='hindsight', N_ticks=0, max_run_length=1500)#max_run_length)
    ax = axs[-1]
    ax.xaxis.set_major_locator(years)
    ax.xaxis.set_major_formatter(yearsFmt)
    ax.xaxis.set_minor_locator(months)
    ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
    
    plt.show()
# Out:
# tau 1500.0
# tau 3000.0
# tau 6000.0
# tau 12000.0
# tau 24000.0

# %%
h = 1./10000
p0 = .5
#max_run_length = 4500 #int(6/h)
p_bar, r_bar, beliefs = bcp.inference(data_mobileos[ind_tweets], h=h, p0=p0)#, max_T=max_run_length)

p_hat_mobileos, r_hat = bcp.readout(p_bar, r_bar, beliefs, mode='hindsight')

# %%
fig, ax = plt.subplots(figsize=(fig_width, fig_width/1.6180))

#p_hat[np.abs(np.gradient(p_hat))>.1] = np.nan
#ax.plot(datetimes[ind_tweets], p_hat_mobileos, c='r')
ax.fill_between(datetimes[ind_tweets], p_hat_mobileos, 0, color='b')
ax.fill_between(datetimes[ind_tweets], p_hat_mobileos, 1, color='r')

if True:
    ax.xaxis.set_major_locator(years)
    ax.xaxis.set_major_formatter(yearsFmt)
    ax.xaxis.set_minor_locator(months)
else:
    ax.xaxis.set_major_locator(months)
    ax.xaxis.set_major_formatter(monthsFmt)

for tick in ax.get_xticklabels():
    tick.set_rotation(45)


#ax.set_xlim(datetime.datetime(2015, 6, 15, 12, 21, 4, tzinfo=datetime.timezone.utc), datetime.datetime(2017, 12, 31, 18, 59, 4, tzinfo=datetime.timezone.utc))
ax.set_xlim(datetime.datetime(2015, 1, 1, 12, 21, 4, tzinfo=datetime.timezone.utc))

#ax.set_yscale('log')
ax.set_ylim(0, 1)

ax.set_xlabel('Date', fontsize=22)
ax.set_ylabel('Estimated probability tweet is from staff', fontsize=22);

# %% [markdown]
# ## detecting change points for some words

# %%
word = 'america'
contains_word = np.array([(word in data_text) for data_text in data_texts])
print(sum(contains_word), 'tweets contain the word "', word, '" on a total of ', n_tweets, 'tweets')
p0 = sum(contains_word) / n_tweets
print('That is, an average probability of p0 = ', p0)
# Out:
# 1983 tweets contain the word " america " on a total of  14366 tweets
# That is, an average probability of p0 =  0.13803424752888765

# %%
h = 1/1500
max_run_length = int(6/h)
p0 = sum(contains_word) / n_tweets

# %%
p_bar, r, beliefs = bcp.inference(contains_word[ind_tweets], h=h, p0=p0)

# %%
fig, axs = bcp.plot_inference(contains_word[ind_tweets], None, p_bar, r, beliefs, mode='hindsight', max_run_length=max_run_length)
ax = axs[-1]
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(yearsFmt)
ax.xaxis.set_minor_locator(months)
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')

# %% [markdown]
# ## wraping things up

# %%
# !ls -ltr -fr /tmp/data_cache
# Out:
# ls: /tmp/data_cache: No such file or directory

# %% [raw]
# !rm -fr /tmp/data_cache

# %%
def analyze(words, mode_, fig_width=8):
    fixed_window_size = 200
    fig, ax = plt.subplots(figsize=(fig_width, fig_width/1.6180))


    print ('mode', mode_)
    for word, c in zip(words, ['b', 'r', 'k', 'g']): #'?', '!', 

        filename = "/tmp/data_cache/" + word + ".npz"
        try:
            npzfile = np.load(filename)
            p_bar, r_bar, beliefs = npzfile['p_bar'], npzfile['r_bar'], npzfile['beliefs'] 
            #hack # to recompute files 
        except Exception as e:
            print('Computing for word' , word, ' - ', e)
            try:
                import os
                os.mkdir('/tmp/data_cache')
            except:
                pass

            contains_word = np.array([(word in data_text) for data_text in data_texts])
            p0 = sum(contains_word) / n_tweets

            p_bar, r_bar, beliefs = bcp.inference(contains_word[ind_tweets], h=h, p0=p0)#, max_T=max_run_length)

            np.savez(filename, p_bar=p_bar, r_bar=r_bar, beliefs=beliefs)

        if mode_=='fixed': 
            p_hat, r_hat = bcp.readout(p_bar, r_bar, beliefs, mode=mode_, fixed_window_size=fixed_window_size)
        else:
            p_hat, r_hat = bcp.readout(p_bar, r_bar, beliefs, mode=mode_)

        if mode_=='hindsight':
            print (np.gradient(p_hat).min(), np.gradient(p_hat).max())
            highgrad = np.abs(np.gradient(p_hat)) > .2
            p_hat[highgrad] = p_hat[highgrad+1]

        ax.plot(datetimes[ind_tweets], p_hat, c=c, label=word)
        #ax.plot(datetimes)


    #datemin = datetime.date(datetimes.min(), 1, 1)
    #datemax = datetime.date(datetimes.max() + 1, 1, 1)
    #ax.set_xlim(datemin, datemax)
    if True:
        ax.xaxis.set_major_locator(years)
        ax.xaxis.set_major_formatter(yearsFmt)
        ax.xaxis.set_minor_locator(months)
    else:
        ax.xaxis.set_major_locator(months)
        ax.xaxis.set_major_formatter(monthsFmt)
    #ax.xaxis.set_minor_locator(months)
    #ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
    #ax.set_yscale('log')
    for tick in ax.get_xticklabels():
        tick.set_rotation(45)

    ax.set_xlabel('Date')
    ax.set_ylabel('Estimated probability')    
    ax.legend(loc='best')
    #ax.set_xlim(datetime.datetime(2015, 6, 15, 12, 21, 4, tzinfo=datetime.timezone.utc), datetime.datetime(2017, 12, 31, 18, 59, 4, tzinfo=datetime.timezone.utc))

    ax.set_xlim(datetime.datetime(2015, 1, 1, 12, 21, 4, tzinfo=datetime.timezone.utc))
    ax.set_ylim(0, 1)


    return fig, ax

modes = ['fixed', 'expectation', 'max', 'hindsight', ]
modes = ['fixed', 'hindsight', ]
modes = ['fixed', 'mean', 'max', 'hindsight', ]
modes = ['hindsight', ]


for words in [['fake', 'news', 'america', 'russia'], 
              ['obama', 'hillary', 'putin', 'pence'],
              ['golf', 'crazy', 'weak', 'joke'],
              ['obama', 'hillary', 'crooked', 'CNN'],
              ['badly', 'guns', 'crazy', 'funny'],
              ['covfefe', 'counsel', 'crooked', 'lightweight'],
              ['great', 'amazing', 'bad', 'sad'],
             ]:
    for i_mode, mode_ in enumerate(modes):
        fig, ax = analyze(words, mode_)
        plt.show()
        #import os
        #fig.savefig(os.path.join('../AnticipatorySPEM/figures', 'trump_' + mode_ + '.png'), dpi=400)
# Out:
# mode hindsight
# Computing for word fake  -  [Errno 2] No such file or directory: '/tmp/data_cache/fake.npz'
# -0.10061038152218099 0.1331415001185247
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-f2677032e274> in <module>
#      83              ]:
#      84     for i_mode, mode_ in enumerate(modes):
# ---> 85         fig, ax = analyze(words, mode_)
#      86         plt.show()
#      87         #import os
#
# <ipython-input-32-f2677032e274> in analyze(words, mode_, fig_width)
#      35             print (np.gradient(p_hat).min(), np.gradient(p_hat).max())
#      36             highgrad = np.abs(np.gradient(p_hat)) > .2
# ---> 37             p_hat[highgrad] = p_hat[highgrad+1]
#      38
#      39         ax.plot(datetimes[ind_tweets], p_hat, c=c, label=word)
#
# ValueError: NumPy boolean array indexing assignment cannot assign 14366 input values to the 0 output values where the mask is true

# %%
for i_mode, mode_ in enumerate(modes):
    fig, ax = plt.subplots(figsize=(fig_width, fig_width/1.6180))

    print('mode ', mode_)

    for word, c in zip(words, ['b', 'r', 'k', 'g']): #'?', '!', 

        filename = "/tmp/data_cache/" + word + ".npz"
        try:
            npzfile = np.load(filename)
            p_bar, r_bar, beliefs = npzfile['p_bar'], npzfile['r_bar'], npzfile['beliefs'] 
            #hack # to recompute files 
        except Exception as e:
            print('Computing for word' , word, ' - ', e)
            try:
                import os
                os.mkdir('/tmp/data_cache')
            except:
                pass

            contains_word = np.array([(word in data_text) for data_text in data_texts])
            p0 = sum(contains_word) / n_tweets

            p_bar, r_bar, beliefs = bcp.inference(contains_word[ind_tweets], h=h, p0=p0)#, max_T=max_run_length)

            np.savez(filename, p_bar=p_bar, r_bar=r_bar, beliefs=beliefs)

            
        if mode_=='fixed': 
            fixed_window_size = 200
            p_hat, r_hat = bcp.readout(p_bar, r_bar, beliefs, mode=mode_, fixed_window_size=fixed_window_size)
        else:
            p_hat, r_hat = bcp.readout(p_bar, r_bar, beliefs, mode=mode_)

        if mode_=='hindsight':
            print (np.gradient(p_hat).min(), np.gradient(p_hat).max())
            highgrad = np.abs(np.gradient(p_hat)) > .2
            p_hat[highgrad] = p_hat[highgrad+1]

        h = 1./10000
        p0 = .5
        #max_run_length = 4500 #int(6/h)
        p_bar, r_bar, beliefs = bcp.inference(data_mobileos[ind_tweets], h=h, p0=p0)#, max_T=max_run_length)

        p_hat_mobileos, r_hat = bcp.readout(p_bar, r_bar, beliefs, mode=mode_)

        ax.scatter(p_hat_mobileos, p_hat, c=c, label=word, alpha=.2)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, .3)

    ax.set_xlabel('Probability OS')
    ax.set_ylabel('Probability word');

    plt.show()
# Out:
# mode  hindsight
# -0.10061038152218099 0.1331415001185247
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-fba411b90006> in <module>
#      36             print (np.gradient(p_hat).min(), np.gradient(p_hat).max())
#      37             highgrad = np.abs(np.gradient(p_hat)) > .2
# ---> 38             p_hat[highgrad] = p_hat[highgrad+1]
#      39
#      40         h = 1./10000
#
# ValueError: NumPy boolean array indexing assignment cannot assign 14366 input values to the 0 output values where the mask is true
